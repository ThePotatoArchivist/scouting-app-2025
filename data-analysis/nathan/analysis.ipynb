# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pymongo import MongoClient
import time

# %%
DEBUG=True
USE_DATABASE=True

# %%
if USE_DATABASE:
    client = MongoClient("mongodb://192.168.1.200:27017")
    db = client["test"] # Connect to db 'test'
    
    # Get data from matchapps collection
    matchapps_collection = db["matchapps"]
    match_df = pd.json_normalize(matchapps_collection.find())

    # Save a backup for later use
    match_df.to_csv(f"matchapps_backup_{time.time()}.csv")

    # Get data from superapps collection
    superapps_collection = db["superapps"]
    super_df = pd.json_normalize(superapps_collection.find())
    super_df.to_csv(f"superapps_backup_{time.time()}.csv")
else:
    match_df = pd.read_csv("matchapps.csv")
    super_df = pd.read_csv("superapps.csv")

match_df.sort_values("metadata.matchNumber", inplace=True)
match_df
# Out:
#                           _id  leftStartingZone    climb  __v  \
# 0    67c344ea114fd247353f8e0f              True  shallow    0
# 25   67c352cd114fd247353f8ec8              True     none    0
# 52   67c35338114fd247353f8fc4              True     park    0
# 13   67c352cd114fd247353f8e98              True     park    0
# 37   67c352e2114fd247353f8ef8              True     deep    0
# ..                        ...               ...      ...  ...
# 417  67c4ab98c08944667710f99b              True     park    0
# 408  67c4ab8fc08944667710f979              True   failed    0
# 399  67c4ab81c08944667710f953              True     park    0
# 426  67c4abb1c08944667710fa2b              True   failed    0
# 435  67c4abc9c08944667710fabc             False     deep    0
#
#     metadata.scouterName  metadata.matchNumber  metadata.robotTeam  \
# 0                Kiinon2                     1              3255.0
# 25                Nathan                     1              2375.0
# 52             Christian                     1               399.0
# 13                                           1              1388.0
# 37              Chiamaka                     1              2543.0
# ..                   ...                   ...                 ...
# 417                 Zach                    71              2543.0
# 408             Joaquin                     71              4201.0
# 399                 Mila                    71              8119.0
# 426                 Soso                    71              8891.0
# 435                 Amy                     71              3863.0
#
#     metadata.robotPosition startingZone.start1 startingZone.start2  ...  \
# 0                   blue_1                True               False  ...
# 25                  blue_3               False               False  ...
# 52                  blue_2               False                True  ...
# 13                   red_2               False               False  ...
# 37                   red_1               False                True  ...
# ..                     ...                 ...                 ...  ...
# 417                 blue_2               False               False  ...
# 408                  red_1               False                True  ...
# 399                  red_2               False               False  ...
# 426                 blue_1               False               False  ...
# 435                 blue_3                True               False  ...
#
#     autoAlgae.netRobot autoAlgae.processor autoAlgae.remove  teleCoral.L1  \
# 0                    0                   0                0             0
# 25                   0                   0                0             0
# 52                   0                   0                0             0
# 13                   0                   0                0             0
# 37                   0                   0                0             0
# ..                 ...                 ...              ...           ...
# 417                  0                   0                1             0
# 408                  0                   0                0             0
# 399                  0                   0                0             0
# 426                  0                   0                0             0
# 435                  0                   0                1             1
#
#      teleCoral.L2 teleCoral.L3  teleCoral.L4  teleAlgae.netRobot  \
# 0               0            0             0                   1
# 25              1            3             0                   0
# 52              0            0             0                   0
# 13              0            1             8                   0
# 37              0            0             0                   0
# ..            ...          ...           ...                 ...
# 417             2            0             2                   0
# 408             0            3             7                   0
# 399             2            3             0                   0
# 426             1            0             2                   2
# 435             0            8             0                   0
#
#      teleAlgae.processor  teleAlgae.remove
# 0                      0                 0
# 25                     0                 1
# 52                     0                 0
# 13                     0                 0
# 37                     5                 1
# ..                   ...               ...
# 417                    0                 0
# 408                    0                 1
# 399                    1                 3
# 426                    0                 2
# 435                    2                 0
#
# [436 rows x 36 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Things I've noticed:
# - Robots scoring on reef while not being marked for leave
# - Crazy amounts scored in some matches
# - Duplicate matches
# - Database not cleared ahead of time - some dummy data left over

# %%
# Robots scoring on reef while not being marked for leave
match_df[
    (~match_df["leftStartingZone"]) & (
    (match_df["autoAlgae.netRobot"] > 0) |
    (match_df["autoAlgae.processor"] > 0) |
    (match_df["autoAlgae.remove"] > 0) |
    (match_df["autoCoral.L1"] > 0) |
    (match_df["autoCoral.L2"] > 0) |
    (match_df["autoCoral.L3"] > 0) |
    (match_df["autoCoral.L4"] > 0))
][
    ["metadata.robotTeam", "metadata.matchNumber", "leftStartingZone"] +
    ["autoAlgae.netRobot", "autoAlgae.processor", "autoAlgae.remove"] +
    ["autoCoral.L{}".format(x) for x in range(1, 5)]
]
# Out:
#      metadata.robotTeam  metadata.matchNumber  leftStartingZone  \
# 4                 610.0                     1             False
# 7                2102.0                     3             False
# 29               2584.0                     5             False
# 9                8015.0                     6             False
# 66               1159.0                     7             False
# 117              3598.0                    18             False
# 139              3863.0                    23             False
# 151              8015.0                    27             False
# 201              3255.0                    35             False
# 225              2584.0                    36             False
# 226               498.0                    37             False
# 227              3863.0                    38             False
# 264               498.0                    46             False
# 343              4400.0                    57             False
# 361              3598.0                    59             False
# 358              3863.0                    60             False
# 369              5817.0                    62             False
# 402              3255.0                    65             False
# 404              4400.0                    67             False
# 422             10147.0                    67             False
# 424               702.0                    69             False
# 415               399.0                    69             False
# 433              8015.0                    69             False
# 435              3863.0                    71             False
#
#      autoAlgae.netRobot  autoAlgae.processor  autoAlgae.remove  autoCoral.L1  \
# 4                     0                    0                 0             0
# 7                     0                    0                 1             1
# 29                    1                    0                 0             0
# 9                     0                    0                 0             0
# 66                    0                    0                 0             1
# 117                   0                    0                 0             0
# 139                   0                    0                 1             0
# 151                   0                    0                 0             0
# 201                   0                    0                 0             0
# 225                   1                    0                 0             0
# 226                   0                    0                 0             0
# 227                   0                    0                 1             0
# 264                   0                    0                 0             1
# 343                   0                    0                 0             0
# 361                   0                    0                 1             1
# 358                   0                    0                 1             1
# 369                   0                    0                 0             0
# 402                   0                    0                 0             0
# 404                   0                    0                 0             0
# 422                   0                    0                 0             1
# 424                   0                    0                 0             0
# 415                   0                    0                 0             0
# 433                   0                    0                 0             0
# 435                   0                    0                 1             0
#
#      autoCoral.L2  autoCoral.L3  autoCoral.L4
# 4               1             0             0
# 7               0             0             0
# 29              0             0             1
# 9               0             0             1
# 66              0             0             0
# 117             0             0             1
# 139             0             1             0
# 151             0             1             4
# 201             0             0             1
# 225             0             0             1
# 226             0             0             1
# 227             0             0             0
# 264             0             0             0
# 343             0             0             1
# 361             0             0             0
# 358             0             0             0
# 369             0             0             2
# 402             0             1             1
# 404             0             0             1
# 422             0             0             0
# 424             0             0             1
# 415             0             0             1
# 433             0             0             1
# 435             0             0             0

# %%
# Indexes below all have leave marked as false and should be true,
# manually verified by watching match data
incorrect_leave_indexes = [4, 7, 9, 29, 66, 117, 139, 151, 201, 225, 226, 227, 264]

for i in incorrect_leave_indexes:
    match_df.loc[i, "leftStartingZone"] = True

match_df[match_df.index.isin(incorrect_leave_indexes)]
# Out:
#                           _id  leftStartingZone    climb  __v  \
# 4    67c34e9b114fd247353f8e74              True     none    0
# 7    67c34e9b114fd247353f8e7d              True     park    0
# 29   67c352cd114fd247353f8ed0              True     none    0
# 9    67c34e9b114fd247353f8e81              True     none    0
# 66   67c366f2114fd247353f908d              True  shallow    0
# 117  67c36a6c114fd247353f91fb              True     deep    0
# 139  67c3819d3822051181ced053              True   failed    0
# 151  67c383273822051181ced07b              True     park    0
# 201  67c39027a522b4c28eabe134              True   failed    0
# 225  67c3a03ba522b4c28eabe1f3              True     deep    0
# 226  67c3a03ba522b4c28eabe1f5              True  shallow    0
# 227  67c3a03ba522b4c28eabe1f7              True  shallow    0
# 264  67c3a7b3a522b4c28eabe311              True     deep    0
#
#     metadata.scouterName  metadata.matchNumber  metadata.robotTeam  \
# 4                 Carlos                     1               610.0
# 7                 Carlos                     3              2102.0
# 29                Nathan                     5              2584.0
# 9                 Carlos                     6              8015.0
# 66              Kkinnon2                     7              1159.0
# 117             David G.                    18              3598.0
# 139             David G.                    23              3863.0
# 151                Josie                    27              8015.0
# 201              Stephen                    35              3255.0
# 225                Josie                    36              2584.0
# 226                Josie                    37               498.0
# 227                Josie                    38              3863.0
# 264              DeNeefe                    46               498.0
#
#     metadata.robotPosition startingZone.start1 startingZone.start2  ...  \
# 4                    red_3                True               False  ...
# 7                    red_3                True               False  ...
# 29                  blue_3               False                True  ...
# 9                    red_3               False                True  ...
# 66                  blue_1               False                True  ...
# 117                  red_3               False                True  ...
# 139                  red_3               False               False  ...
# 151                  red_1               False               False  ...
# 201                  red_2               False               False  ...
# 225                  red_1               False                True  ...
# 226                  red_1               False               False  ...
# 227                  red_1               False               False  ...
# 264                  red_3               False               False  ...
#
#     autoAlgae.netRobot autoAlgae.processor autoAlgae.remove  teleCoral.L1  \
# 4                    0                   0                0             0
# 7                    0                   0                1             0
# 29                   1                   0                0             0
# 9                    0                   0                0             0
# 66                   0                   0                0             0
# 117                  0                   0                0             0
# 139                  0                   0                1             0
# 151                  0                   0                0             0
# 201                  0                   0                0             0
# 225                  1                   0                0             0
# 226                  0                   0                0             1
# 227                  0                   0                1             0
# 264                  0                   0                0             0
#
#      teleCoral.L2 teleCoral.L3  teleCoral.L4  teleAlgae.netRobot  \
# 4               1            4             5                   0
# 7               0            0             0                   0
# 29              1            2             2                   0
# 9               0            0             6                   0
# 66              0            0             0                   0
# 117             0            0             2                   0
# 139             1            5             0                   0
# 151             0            0             0                   0
# 201             0            4             7                   0
# 225             0            0             1                   1
# 226             0            0             6                   0
# 227             0            0             0                   0
# 264             0            3             4                   0
#
#      teleAlgae.processor  teleAlgae.remove
# 4                      0                 2
# 7                      2                 0
# 29                     0                 2
# 9                      0                 0
# 66                     0                 0
# 117                    0                 0
# 139                    1                 2
# 151                    0                 0
# 201                    0                 3
# 225                    0                 2
# 226                    0                 0
# 227                    4                 0
# 264                    0                 3
#
# [13 rows x 36 columns]

# %%
# Robots scoring crazy amounts, imposing reasonable defaults
match_df[
    (match_df["autoCoral.L1"] > 5) |
    (match_df["autoCoral.L2"] > 5) |
    (match_df["autoCoral.L3"] > 5) |
    (match_df["autoCoral.L4"] > 5) |
    (match_df["teleCoral.L1"] > 10) |
    (match_df["teleCoral.L2"] > 10) |
    (match_df["teleCoral.L3"] > 10) |
    (match_df["teleCoral.L4"] > 10)
][
    ["metadata.robotTeam", "metadata.matchNumber"] +
    ["autoCoral.L{}".format(x) for x in range(1, 5)] +
    ["teleCoral.L{}".format(x) for x in range(1, 5)]
]
# Out:
#      metadata.robotTeam  metadata.matchNumber  autoCoral.L1  autoCoral.L2  \
# 335              3863.0                    43             0             0
#
#      autoCoral.L3  autoCoral.L4  teleCoral.L1  teleCoral.L2  teleCoral.L3  \
# 335             0             0             3             0            22
#
#      teleCoral.L4
# 335             0

# %%
# Index 335 - update values to:
# 4 L1
# 8 L3

match_df.loc[335, "teleCoral.L1"] = 4
match_df.loc[335, "teleCoral.L3"] = 8

match_df[match_df.index == 335][
    ["metadata.robotTeam", "metadata.matchNumber"] +
    ["autoCoral.L{}".format(x) for x in range(1, 5)] +
    ["teleCoral.L{}".format(x) for x in range(1, 5)]
]
# Out:
#      metadata.robotTeam  metadata.matchNumber  autoCoral.L1  autoCoral.L2  \
# 335              3863.0                    43             0             0
#
#      autoCoral.L3  autoCoral.L4  teleCoral.L1  teleCoral.L2  teleCoral.L3  \
# 335             0             0             4             0             8
#
#      teleCoral.L4
# 335             0

# %%
# Find duplicate matches
# match_df.groupby(["metadata.robotTeam", "metadata.matchNumber"]).count() != 1
# match_df.groupby("metadata.matchNumber").count() != 6

# %%
# Find teams that aren't at this tournament
match_df[match_df["metadata.robotTeam"] == 6904]
# Out:
#                           _id  leftStartingZone climb  __v  \
# 342  67c48f7ec08944667710f7d8             False  deep    0
#
#     metadata.scouterName  metadata.matchNumber  metadata.robotTeam  \
# 342              Vanessa                    21              6904.0
#
#     metadata.robotPosition startingZone.start1 startingZone.start2  ...  \
# 342                  red_1                 NaN                 NaN  ...
#
#     autoScore teleScore climb.park  climb.shallow  climb.deep endgameScore  \
# 342         0        27      False          False        True           12
#
#      totalScore  metadata.robotColorIsBlue  autoScoreRightReef  \
# 342          39                      False               False
#
#      autoScoreLeftReef
# 342              False
#
# [1 rows x 46 columns]

# %% [markdown]
# # Adding New Fields

# %%
# Grab a random sample match
DEBUG and match_df[(match_df["metadata.robotTeam"] == 4201) & (match_df["metadata.matchNumber"] == 8)]
# Out:
#                          _id  leftStartingZone climb  __v  \
# 59  67c35339114fd247353f8fdd              True  park    0
#
#    metadata.scouterName  metadata.matchNumber  metadata.robotTeam  \
# 59            Christian                     8              4201.0
#
#    metadata.robotPosition startingZone.start1 startingZone.start2  ...  \
# 59                 blue_2               False                True  ...
#
#    autoAlgae.netRobot autoAlgae.processor autoAlgae.remove  teleCoral.L1  \
# 59                  0                   0                0             0
#
#     teleCoral.L2 teleCoral.L3  teleCoral.L4  teleAlgae.netRobot  \
# 59             2            5             4                   0
#
#     teleAlgae.processor  teleAlgae.remove
# 59                    0                 0
#
# [1 rows x 36 columns]

# %%
# Add columns for auto, tele, and endgame score
match_df["autoScore"] = (
    match_df["leftStartingZone"] * 3 +
    match_df["autoCoral.L1"] * 3 +
    match_df["autoCoral.L2"] * 4 +
    match_df["autoCoral.L3"] * 6 +
    match_df["autoCoral.L4"] * 7 +
    match_df["autoAlgae.processor"] * 6 +
    match_df["autoAlgae.netRobot"] * 4
)

match_df["teleScore"] = (
    match_df["teleCoral.L1"] * 2 +
    match_df["teleCoral.L2"] * 3 +
    match_df["teleCoral.L3"] * 4 +
    match_df["teleCoral.L4"] * 5 +
    match_df["teleAlgae.processor"] * 6 +
    match_df["teleAlgae.netRobot"] * 4
)

match_df["climb.park"] = match_df["climb"] == "park"
match_df["climb.shallow"] = match_df["climb"] == "shallow"
match_df["climb.deep"] = match_df["climb"] == "deep"

match_df["endgameScore"] = (
    match_df["climb.park"] * 2 +
    match_df["climb.shallow"] * 6 +
    match_df["climb.deep"] * 12
)

match_df["totalScore"] = (
    match_df["autoScore"] +
    match_df["teleScore"] +
    match_df["endgameScore"]
)

# %%
# Grab a random sample match to verify
DEBUG and match_df[match_df["metadata.robotTeam"] == 3255][["autoCoral.L1", "autoCoral.L2", "autoCoral.L3", "autoCoral.L4", "autoAlgae.processor", "autoAlgae.netRobot", "autoScore"]]
# Out:
#      autoCoral.L1  autoCoral.L2  autoCoral.L3  autoCoral.L4  \
# 0               0             0             0             0
# 94              0             0             0             2
# 109             1             0             0             0
# 142             0             0             0             1
# 201             0             0             0             1
# 213             0             0             0             1
# 277             0             0             0             2
# 345             0             1             2             1
# 370             0             0             0             2
# 402             0             0             1             1
#
#      autoAlgae.processor  autoAlgae.netRobot  autoScore
# 0                      0                   0          3
# 94                     0                   0         17
# 109                    0                   0          6
# 142                    0                   0         10
# 201                    0                   0         10
# 213                    0                   0         10
# 277                    0                   0         17
# 345                    0                   1         30
# 370                    0                   0         17
# 402                    0                   0         13

# %%
# Grab a random sample match to verify
DEBUG and match_df[match_df["metadata.robotTeam"] == 3255][["leftStartingZone", "teleCoral.L1", "teleCoral.L2", "teleCoral.L3", "teleCoral.L4", "teleAlgae.processor", "teleAlgae.netRobot", "teleScore"]]
# Out:
#      leftStartingZone  teleCoral.L1  teleCoral.L2  teleCoral.L3  teleCoral.L4  \
# 0                True             0             0             0             0
# 94               True             0             5             2             3
# 109              True             2             0             0             4
# 142              True             0             0             0             1
# 201              True             0             0             4             7
# 213              True             0             5             4             3
# 277              True             0             0             5             6
# 345              True             2             3             2             5
# 370              True             0             2             5             2
# 402             False             0             1             6             5
#
#      teleAlgae.processor  teleAlgae.netRobot  teleScore
# 0                      0                   1          4
# 94                     0                   1         42
# 109                    0                   2         32
# 142                    0                   5         25
# 201                    0                   0         51
# 213                    0                   1         50
# 277                    0                   4         66
# 345                    0                   3         58
# 370                    0                   2         44
# 402                    0                   3         64

# %%
# Grab a random sample match to verify
DEBUG and match_df[match_df["metadata.robotTeam"] == 3255][["climb.park", "climb.shallow", "climb.deep", "endgameScore"]]
# Out:
#      climb.park  climb.shallow  climb.deep  endgameScore
# 0         False           True       False             6
# 94        False          False        True            12
# 109       False          False        True            12
# 142       False          False        True            12
# 201       False          False       False             0
# 213       False          False        True            12
# 277       False          False       False             0
# 345       False           True       False             6
# 370       False          False        True            12
# 402        True          False       False             2

# %%
# Grab a random sample match to verify
DEBUG and match_df[match_df["metadata.robotTeam"] == 3255][["autoScore", "teleScore", "endgameScore", "totalScore"]]
# Out:
#      autoScore  teleScore  endgameScore  totalScore
# 0            3          4             6          13
# 94          17         42            12          71
# 109          6         32            12          50
# 142         10         25            12          47
# 201         10         51             0          61
# 213         10         50            12          72
# 277         17         66             0          83
# 345         30         58             6          94
# 370         17         44            12          73
# 402         13         64             2          79

# %%
# Add columns for whether teams have scored on the side of the reef in auto
match_df["metadata.robotColorIsBlue"] = (
    (match_df["metadata.robotPosition"] == "blue_1") |
    (match_df["metadata.robotPosition"] == "blue_2") |
    (match_df["metadata.robotPosition"] == "blue_3")
)

# Calculate if a team scored on the right side of the reef, from the perspective of the barge
match_df["autoScoreRightReef"] = (
    match_df["metadata.robotColorIsBlue"] & (match_df["placement.deposit1"] | match_df["placement.deposit6"]) |
    ~match_df["metadata.robotColorIsBlue"] & (match_df["placement.deposit3"] | match_df["placement.deposit4"])
)

# Calculate if a team scored on the left side of the reef, from the perspective of the barge
match_df["autoScoreLeftReef"] = (
    match_df["metadata.robotColorIsBlue"] & (match_df["placement.deposit3"] | match_df["placement.deposit4"]) |
    ~match_df["metadata.robotColorIsBlue"] & (match_df["placement.deposit1"] | match_df["placement.deposit6"])
)

# %%
# Grab a random sample match to verify
DEBUG and match_df[match_df["autoScoreRightReef"] | match_df["autoScoreLeftReef"]][["metadata.matchNumber", "metadata.robotTeam", "metadata.robotPosition", "placement.deposit1", "placement.deposit2", "placement.deposit3", "placement.deposit4", "placement.deposit5", "placement.deposit6", "autoScoreRightReef", "autoScoreLeftReef"]]
# Out:
#      metadata.matchNumber  metadata.robotTeam metadata.robotPosition  \
# 0                       1              3255.0                 blue_1
# 4                       1               610.0                  red_3
# 7                       3              2102.0                  red_3
# 19                      7              5515.0                  red_2
# 11                      8              5817.0                  red_3
# 12                      9               702.0                  red_3
# 22                     10              4414.0                  red_2
# 49                     10             10147.0                  red_3
# 35                     11              9599.0                 blue_3
# 47                     11               498.0                  red_1
# 71                     12              6657.0                 blue_1
# 102                    13              6658.0                 blue_2
# 72                     13             10120.0                 blue_1
# 104                    15              3863.0                 blue_2
# 74                     15              6766.0                 blue_1
# 105                    16               702.0                 blue_2
# 127                    16              6560.0                 blue_3
# 129                    18              2102.0                 blue_3
# 77                     18              4414.0                 blue_1
# 109                    20              3255.0                 blue_2
# 88                     20              4400.0                  red_2
# 80                     21             10147.0                 blue_1
# 111                    22               498.0                 blue_2
# 154                    24              2658.0                 blue_2
# 148                    24              4414.0                  red_1
# 149                    25              6766.0                  red_1
# 161                    25              4400.0                 blue_3
# 155                    25               702.0                 blue_2
# 138                    27             10147.0                  red_2
# 199                    33              4414.0                  red_2
# 201                    35              3255.0                  red_2
# 209                    36              2102.0                  red_2
# 251                    37             10120.0                 blue_3
# 211                    38              5817.0                  red_2
# 242                    38              1388.0                 blue_2
# 236                    39              4400.0                 blue_1
# 12                False               True
# 22                False               True
# 49                 True              False
# 35                False               True
# 47                 True              False
# 71                False               True
# 102               False               True
# 72                 True              False
# 104                True              False
# 74                False               True
# 105               False               True
# 127                True              False
# 129                True              False
# 77                False               True
# 109               False               True
# 88                 True              False
# 80                 True              False
# 111                True              False
# 154               False               True
# 148               False               True
# 149               False               True
# 161                True              False
# 155               False               True
# 138               False               True
# 199               False               True
# 201                True              False
# 209               False               True
# 251                True              False
# 211               False               True
# 242               False               True
# 236                True              False
# 213                True              False
# 215                True              False
# 247                True              False
# 336                True              False
# 249               False               True
# 268                True              False
# 295                True              False
# 275               False               True
# 277               False               True
# 314                True              False
# 306                True              False
# 310               False               True
# 318               False               True
# 343                True              False
# 341               False               True
# 340               False               True
# 372               False               True
# 348               False               True
# 384               False               True

# %%
team_df = pd.DataFrame()

# %%
# For each of the columns below, find only the average
AVG_COLUMNS = (
    ["startingZone.start{}".format(x) for x in range(1, 4)] +
    ["pickupLocation.source{}".format(x) for x in range(1, 3)] +
    ["pickupLocation.ground{}".format(x) for x in range(1, 4)] +
    ["placement.deposit{}".format(x) for x in range(1, 7)] +
    ["climb.park", "climb.shallow", "climb.deep", "autoScoreRightReef", "autoScoreLeftReef"]
)

for c in AVG_COLUMNS:
    team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()

# %%
# For each of the columns below, find statistical metrics for each (min, max, avg, std)
STAT_COLUMNS = (
    ["autoCoral.L{}".format(x) for x in range(1, 5)] +
    ["teleCoral.L{}".format(x) for x in range(1, 5)] +
    ["autoAlgae.netRobot", "autoAlgae.processor", "autoAlgae.remove"] +
    ["teleAlgae.netRobot", "teleAlgae.processor", "teleAlgae.remove"] +
    ["autoScore", "teleScore", "endgameScore", "totalScore"]
)

for c in STAT_COLUMNS:
    team_df[f"{c}.min"] = match_df.groupby("metadata.robotTeam")[c].min()
    team_df[f"{c}.max"] = match_df.groupby("metadata.robotTeam")[c].max()
    team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()
    team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()

    # We also want to calculate these metrics for different variations of matches being dropped.
    for n in range(1, 3):
        # Start by removing the top and bottom `n` matches for a team by finding
        # the indexes of the matches we want to keep
        indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
        filtered_df = match_df[match_df.index.isin(indexes_to_keep)]

        # With our new filtered dataframe, compute statistic metrics
        team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
        team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
        team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
        team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# Out:
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min"] = match_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max"] = match_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min"] = match_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max"] = match_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min"] = match_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max"] = match_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min"] = match_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max"] = match_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min"] = match_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max"] = match_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min"] = match_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max"] = match_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min"] = match_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max"] = match_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# ...
#   team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min"] = match_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max"] = match_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min"] = match_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max"] = match_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg"] = match_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std"] = match_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()
# /tmp/ipykernel_313928/2394994711.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   indexes_to_keep = match_df.groupby("metadata.robotTeam").apply(lambda x: x.sort_values(c).iloc[n:-n]).index.get_level_values(1)
# /tmp/ipykernel_313928/2394994711.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.min.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].min()
# /tmp/ipykernel_313928/2394994711.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.max.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].max()
# /tmp/ipykernel_313928/2394994711.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.avg.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].mean()
# /tmp/ipykernel_313928/2394994711.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df[f"{c}.std.drop{n}"] = filtered_df.groupby("metadata.robotTeam")[c].std()

# %%
DEBUG and team_df[team_df.index == 4201][["autoCoral.L4.avg", "autoCoral.L4.avg.drop1", "autoCoral.L4.avg.drop2"]]
# Out:
#                     autoCoral.L4.avg  autoCoral.L4.avg.drop1  \
# metadata.robotTeam
# 4201.0                           0.5                     0.5
#
#                     autoCoral.L4.avg.drop2
# metadata.robotTeam
# 4201.0                                 0.5

# %%
DEBUG and match_df[match_df["metadata.robotTeam"] == 4201][["metadata.robotTeam", "autoCoral.L4"]]
# Out:
#      metadata.robotTeam  autoCoral.L4
# 59               4201.0             0
# 95               4201.0             1
# 134              4201.0             0
# 203              4201.0             1
# 173              4201.0             1
# 269              4201.0             1
# 329              4201.0             0
# 344              4201.0             0
# 364              4201.0             0
# 408              4201.0             1

# %%
team_df["fouls.avg"] = super_df[[
    "fouls.insideRobot",
    "fouls.protectedZone",
    "fouls.pinning",
    "fouls.multiplePieces",
    "fouls.cageFoul",
    "fouls.other"
]].sum(axis=1).groupby(super_df["metadata.robotTeam"]).mean()
# Out:
# /tmp/ipykernel_313928/1034481741.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df["fouls.avg"] = super_df[[

# %%
DEBUG and team_df["fouls.avg"]
# Out:
# metadata.robotTeam
# 4.0        0.111111
# 114.0      0.111111
# 399.0      0.000000
# 498.0      0.100000
# 610.0      0.111111
# 702.0      0.000000
# 988.0      0.090909
# 991.0      0.222222
# 1159.0     0.222222
# 1388.0     0.000000
# 1452.0     0.100000
# 2102.0     0.100000
# 2375.0     0.181818
# 2485.0     0.400000
# 2543.0     0.000000
# 2584.0     0.300000
# 2658.0     0.444444
# 2839.0     0.400000
# 3255.0     0.333333
# 3598.0     0.111111
# 3647.0     1.222222
# 3759.0     0.000000
# 3863.0     0.000000
# 3881.0     0.300000
# 4201.0     0.000000
# 4400.0     0.555556
# 4414.0     0.100000
# 5025.0     0.000000
# 5137.0     0.000000
# 5515.0     1.200000
# 5817.0     0.000000
# 6560.0     0.900000
# 6657.0     0.222222
# 6658.0     0.444444
# 6766.0     0.181818
# 6885.0     0.000000
# 6904.0          NaN
# 8015.0     0.000000
# 8119.0     0.000000
# 8768.0     0.111111
# 8891.0     0.090909
# 9452.0     0.000000
# 9534.0     0.555556
# 9599.0     0.000000
# 9772.0     0.600000
# 10120.0    0.000000
# 10147.0    0.000000
# Name: fouls.avg, dtype: float64

# %%
team_df["break.avg"] = super_df[[
    "break.mechanismDmg",
    "break.batteryFall",
    "break.commsFail",
    "break.bumperFall"
]].sum(axis=1).groupby(super_df["metadata.robotTeam"]).mean()
# Out:
# /tmp/ipykernel_313928/634828927.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df["break.avg"] = super_df[[

# %%
DEBUG and team_df["break.avg"]
# Out:
# metadata.robotTeam
# 4.0        0.000000
# 114.0      0.000000
# 399.0      0.000000
# 498.0      0.000000
# 610.0      0.000000
# 702.0      0.000000
# 988.0      0.090909
# 991.0      0.222222
# 1159.0     0.000000
# 1388.0     0.000000
# 1452.0     0.000000
# 2102.0     0.000000
# 2375.0     0.090909
# 2485.0     0.100000
# 2543.0     0.000000
# 2584.0     0.000000
# 2658.0     0.222222
# 2839.0     0.000000
# 3255.0     0.000000
# 3598.0     0.000000
# 3647.0     0.000000
# 3759.0     0.111111
# 3863.0     0.000000
# 3881.0     0.000000
# 4201.0     0.181818
# 4400.0     0.000000
# 4414.0     0.000000
# 5025.0     0.200000
# 5137.0     0.000000
# 5515.0     0.000000
# 5817.0     0.000000
# 6560.0     0.000000
# 6657.0     0.111111
# 6658.0     0.555556
# 6766.0     0.000000
# 6885.0     0.300000
# 6904.0          NaN
# 8015.0     0.000000
# 8119.0     0.000000
# 8768.0     0.000000
# 8891.0     0.090909
# 9452.0     0.000000
# 9534.0     0.000000
# 9599.0     0.000000
# 9772.0     0.400000
# 10120.0    0.000000
# 10147.0    0.000000
# Name: break.avg, dtype: float64

# %%
# All copied from last year, didn't actually check if this works
def safeDivide(a, b):
    return 0 if b == 0 else a / b

team_list = match_df["metadata.robotTeam"].unique().tolist()
team_list = [team for team in team_list if not np.isnan(team)]

team_df["Percent of Matches with No Defense"] = None
team_df["Percent of Matches with Some Defense"] = None
team_df["Percent of Matches with Full Defense"] = None
team_df["Main Defense Type"] = None

for team in team_list:
    
    defense_type_list = super_df.loc[super_df["metadata.robotTeam"] == team, "defense"].tolist()
    
    no_defense_count = 0
    some_defense_count = 0
    full_defense_count = 0
    
    for defense_type in defense_type_list:
        if defense_type == "noDef":
            no_defense_count += 1
        elif defense_type == "someDef":
            some_defense_count += 1
        elif defense_type == "fullDef":
            full_defense_count += 1

    defense_total_count = sum([no_defense_count, some_defense_count, full_defense_count])
        
    team_df.at[team, "Percent of Matches with No Defense"] = safeDivide(no_defense_count, defense_total_count)
    team_df.at[team, "Percent of Matches with Some Defense"] = safeDivide(some_defense_count, defense_total_count)
    team_df.at[team, "Percent of Matches with Full Defense"] = safeDivide(full_defense_count, defense_total_count)
    
    biggest_defense_count = max([no_defense_count, some_defense_count, full_defense_count])
    main_defense_type = ""

    if biggest_defense_count == no_defense_count:
        main_defense_type += "No Defense "
    if biggest_defense_count == some_defense_count:
        main_defense_type += "Some Defense "
    if biggest_defense_count == full_defense_count:
        main_defense_type += "Full Defense"
    
    team_df.at[team, "Main Defense Type"] = main_defense_type
# Out:
# /tmp/ipykernel_313928/1343473457.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df["Percent of Matches with No Defense"] = None
# /tmp/ipykernel_313928/1343473457.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df["Percent of Matches with Some Defense"] = None
# /tmp/ipykernel_313928/1343473457.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df["Percent of Matches with Full Defense"] = None
# /tmp/ipykernel_313928/1343473457.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team_df["Main Defense Type"] = None

# %%
DEBUG and team_df
# Out:
#                    startingZone.start1.avg startingZone.start2.avg  \
# metadata.robotTeam
# 4.0                               0.333333                0.111111
# 114.0                             0.111111                0.555556
# 399.0                             0.222222                0.555556
# 498.0                             0.333333                     0.0
# 610.0                             0.444444                0.111111
# 702.0                             0.333333                0.111111
# 988.0                                  0.3                     0.2
# 991.0                             0.333333                0.111111
# 1159.0                                 0.0                0.666667
# 10147.0                                              0.0
#
#                     Percent of Matches with Full Defense  \
# metadata.robotTeam
# 4.0                                                  0.0
# 114.0                                                0.0
# 399.0                                                0.0
# 498.0                                                0.0
# 610.0                                           0.111111
# 702.0                                                0.0
# 988.0                                           0.454545
# 991.0                                           0.111111
# 1159.0                                          0.111111
# 1388.0                                               0.0
# 1452.0                                               0.0
# 2102.0                                               0.0
# 2375.0                                               0.0
# 2485.0                                               0.0
# 2543.0                                               0.0
# 2584.0                                               0.0
# 2658.0                                               0.0
# 2839.0                                               0.0
# 3255.0                                               0.0
# 3598.0                                               0.0
# 3647.0                                          0.222222
# 3759.0                                               0.0
# 3863.0                                               0.0
# 3881.0                                               0.0
# 4201.0                                               0.0
# 4400.0                                               0.0
# 4414.0                                               0.0
# 5025.0                                               0.0
# 5137.0                                               0.0
# 5515.0                                               0.0
# 5817.0                                               0.0
# 6560.0                                               0.0
# 6657.0                                               0.0
# 6658.0                                          0.111111
# 6766.0                                               0.0
# 6885.0                                               0.0
# 6904.0                                                 0
# 8015.0                                               0.0
# 8119.0                                               0.1
# 8768.0                                               0.0
# 8891.0                                               0.0
# 9452.0                                               0.0
# 9534.0                                          0.333333
# 9599.0                                               0.0
# 9772.0                                               0.4
# 10120.0                                              0.0
# 10147.0                                              0.0
#
#                                        Main Defense Type
# metadata.robotTeam
# 4.0                                          No Defense
# 114.0                                        No Defense
# 399.0                                        No Defense
# 498.0                                        No Defense
# 610.0                                        No Defense
# 702.0                                        No Defense
# 988.0                            No Defense Full Defense
# 991.0                                        No Defense
# 1159.0                                       No Defense
# 1388.0                                       No Defense
# 1452.0                                       No Defense
# 2102.0                                       No Defense
# 2375.0                                       No Defense
# 2485.0                                       No Defense
# 2543.0                                       No Defense
# 2584.0                                       No Defense
# 2658.0                                       No Defense
# 2839.0                                       No Defense
# 3255.0                                       No Defense
# 3598.0                                       No Defense
# 3647.0                                       No Defense
# 3759.0                                       No Defense
# 3863.0                                       No Defense
# 3881.0                                       No Defense
# 4201.0                                       No Defense
# 4400.0                                       No Defense
# 4414.0                                       No Defense
# 5025.0                                       No Defense
# 5137.0                                       No Defense
# 5515.0                                       No Defense
# 5817.0                                       No Defense
# 6560.0                                       No Defense
# 6657.0                                       No Defense
# 6658.0                                       No Defense
# 6766.0                                       No Defense
# 6885.0                                       No Defense
# 6904.0              No Defense Some Defense Full Defense
# 8015.0                                       No Defense
# 8119.0                                       No Defense
# 8768.0                                       No Defense
# 8891.0                                       No Defense
# 9452.0                                       No Defense
# 9534.0                                       No Defense
# 9599.0                                       No Defense
# 9772.0                                      Full Defense
# 10120.0                                      No Defense
# 10147.0                                      No Defense
#
# [47 rows x 241 columns]

# %%
team_df.to_csv("caph_2025_sun.csv")

# %% [markdown]
# # Compare to TBA Data

# %%
EVENT_KEY = "2025caph"

# %%
import requests

params = [

]

url = f"https://www.thebluealliance.com/api/v3/event/{EVENT_KEY}/matches"

resp = requests.get(url=url, params=params)
data = resp.json() # Check the JSON Response Content documentation below

# %%
tba_df = pd.json_normalize(data)

# %%
for i in tba_df.index:
    print(tba_df.columns[i])
# Out:
# actual_time
# comp_level
# event_key
# key
# match_number
# post_result_time
# predicted_time
# set_number
# time
# videos
# winning_alliance
# alliances.blue.dq_team_keys
# alliances.blue.score
# alliances.blue.surrogate_team_keys
# alliances.blue.team_keys
# alliances.red.dq_team_keys
# alliances.red.score
# alliances.red.surrogate_team_keys
# alliances.red.team_keys
# score_breakdown.blue.adjustPoints
# score_breakdown.blue.algaePoints
# score_breakdown.blue.autoBonusAchieved
# score_breakdown.blue.autoCoralCount
# score_breakdown.blue.autoCoralPoints
# score_breakdown.blue.autoLineRobot1
# score_breakdown.blue.autoLineRobot2
# score_breakdown.blue.autoLineRobot3
# score_breakdown.blue.autoMobilityPoints
# score_breakdown.blue.autoPoints
# score_breakdown.blue.autoReef.botRow.nodeA
# score_breakdown.blue.autoReef.botRow.nodeB
# score_breakdown.blue.autoReef.botRow.nodeC
# score_breakdown.blue.autoReef.botRow.nodeD
# score_breakdown.blue.autoReef.botRow.nodeE
# score_breakdown.blue.autoReef.botRow.nodeF
# score_breakdown.blue.autoReef.botRow.nodeG
# score_breakdown.blue.autoReef.botRow.nodeH
# score_breakdown.blue.autoReef.botRow.nodeI
# score_breakdown.blue.autoReef.botRow.nodeJ
# score_breakdown.blue.autoReef.botRow.nodeK
# score_breakdown.blue.autoReef.botRow.nodeL
# score_breakdown.blue.autoReef.midRow.nodeA
# score_breakdown.blue.autoReef.midRow.nodeB
# score_breakdown.blue.autoReef.midRow.nodeC
# score_breakdown.blue.autoReef.midRow.nodeD
# score_breakdown.blue.autoReef.midRow.nodeE
# score_breakdown.blue.autoReef.midRow.nodeF
# score_breakdown.blue.autoReef.midRow.nodeG
# score_breakdown.blue.autoReef.midRow.nodeH
# score_breakdown.blue.autoReef.midRow.nodeI
# score_breakdown.blue.autoReef.midRow.nodeJ
# score_breakdown.blue.autoReef.midRow.nodeK
# score_breakdown.blue.autoReef.midRow.nodeL
# score_breakdown.blue.autoReef.tba_botRowCount
# score_breakdown.blue.autoReef.tba_midRowCount
# score_breakdown.blue.autoReef.tba_topRowCount
# score_breakdown.blue.autoReef.topRow.nodeA
# score_breakdown.blue.autoReef.topRow.nodeB
# score_breakdown.blue.autoReef.topRow.nodeC
# score_breakdown.blue.autoReef.topRow.nodeD
# score_breakdown.blue.autoReef.topRow.nodeE
# score_breakdown.blue.autoReef.topRow.nodeF
# score_breakdown.blue.autoReef.topRow.nodeG
# score_breakdown.blue.autoReef.topRow.nodeH
# score_breakdown.blue.autoReef.topRow.nodeI
# score_breakdown.blue.autoReef.topRow.nodeJ
# score_breakdown.blue.autoReef.topRow.nodeK
# score_breakdown.blue.autoReef.topRow.nodeL
# score_breakdown.blue.autoReef.trough
# score_breakdown.blue.bargeBonusAchieved
# score_breakdown.blue.coopertitionCriteriaMet
# score_breakdown.blue.coralBonusAchieved
# score_breakdown.blue.endGameBargePoints
# score_breakdown.blue.endGameRobot1
# score_breakdown.blue.endGameRobot2
# score_breakdown.blue.endGameRobot3
# score_breakdown.blue.foulCount
# score_breakdown.blue.foulPoints
# score_breakdown.blue.g206Penalty
# score_breakdown.blue.g410Penalty
# score_breakdown.blue.g418Penalty
